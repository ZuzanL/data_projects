# %% [markdown]
# ### Data cleanup
# Real-estate in Czech republic

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import regex as re
from sqlalchemy import create_engine

# %%
df = pd.read_json('real_estate.json')
df
# Out:
#                                               name  \
# 0                          Pronájem bytu 2+1 60 m²
# 1                            Prodej bytu 1+1 35 m²
# 2            Prodej chalupy 110 m², pozemek 331 m²
# 3     Prodej rodinného domu 110 m², pozemek 331 m²
# 4     Prodej rodinného domu 250 m², pozemek 800 m²
# ...                                            ...
# 2195                        Prodej bytu 3+kk 86 m²
# 2196                       Prodej bytu 4+kk 125 m²
# 2197                         Prodej bytu 1+1 38 m²
# 2198                         Prodej bytu 3+1 81 m²
# 2199                        Prodej bytu 1+kk 24 m²
#
#                                  adress            price
# 0          Pod Lesem, Plzeň - Doubravka  15 500 Kč/měsíc
# 1     Úvalská, Karlovy Vary - Drahovice     2 600 000 Kč
# 2                             Sopotnice     1 890 000 Kč
# 3                             Sopotnice     1 890 000 Kč
# 4                                 Jičín     5 890 000 Kč
# ...                                 ...              ...
# 2195                               Srní     9 890 000 Kč
# 2196                Karlovarská, Unhošť     7 999 000 Kč
# 2197          Košická, Praha - Vršovice     5 999 999 Kč
# 2198        Rostovská, Praha - Vršovice    14 857 931 Kč
# 2199    Aloise Rašína, Olomouc - Řepčín     3 250 000 Kč
#
# [2200 rows x 3 columns]

# %% [markdown]
# ##### Creating column "TYPE" (selling / renting)

# %%
# Extracting first word from the name column

df['type'] = df['name'].str.extract(r'(\w+)')
df['type'] = df['type'].str.lower()

# %%
# Finding whether there is any other word in the TYPE column than just pronajem (renting) or prodej (selling)
checking = df[(df['type'] != 'pronájem') & (df['type'] != 'prodej')]
checking
# Out:
#                                                    name  \
# 6     SLEVA: Prodej rodinného domu 166 m², pozemek 1...
# 103                       SLEVA: Prodej bytu 1+kk 50 m²
# 119                       SLEVA: Prodej bytu 1+kk 53 m²
# 120                       SLEVA: Prodej bytu 2+kk 66 m²
# 121                       SLEVA: Prodej bytu 3+kk 89 m²
# 137                       SLEVA: Prodej bytu 3+kk 77 m²
# 190   SLEVA: Prodej rodinného domu 300 m², pozemek 7...
# 225   SLEVA: Pronájem rodinného domu 234 m², pozemek...
# 233                        SLEVA: Prodej bytu 3+1 65 m²
# 281   SLEVA: Prodej rodinného domu 91 m², pozemek 17...
# 282           SLEVA: Prodej chaty 91 m², pozemek 171 m²
# 302                        SLEVA: Prodej bytu 3+1 72 m²
# 349                      SLEVA: Pronájem bytu 1+1 38 m²
# 387                        SLEVA: Prodej bytu 3+1 66 m²
# 409                       SLEVA: Prodej bytu 4+kk 97 m²
# 432   SLEVA: Prodej rodinného domu 211 m², pozemek 9...
# 449   SLEVA: Prodej rodinného domu 144 m², pozemek 5...
# 467   SLEVA: Prodej rodinného domu 117 m², pozemek 9...
# 501                     SLEVA: Pronájem bytu 2+kk 44 m²
# 624                       SLEVA: Prodej bytu 1+kk 22 m²
# 738   SLEVA: Prodej rodinného domu 85 m², pozemek 78...
# 760                       SLEVA: Prodej bytu 3+kk 76 m²
# 816   SLEVA: Prodej rodinného domu 170 m², pozemek 3...
# 880   SLEVA: Prodej vícegeneračního domu 160 m², poz...
# 915   SLEVA: Prodej rodinného domu 210 m², pozemek 9...
# 1025                      SLEVA: Prodej bytu 2+kk 85 m²
# 1138                      SLEVA: Prodej bytu 2+kk 55 m²
# 1144                      SLEVA: Prodej bytu 2+kk 55 m²
# 1249       SLEVA: Prodej chalupy 89 m², pozemek 1269 m²
# 1264  SLEVA: Prodej rodinného domu 105 m², pozemek 6...
# 1290  SLEVA: Prodej rodinného domu 100 m², pozemek 1...
# 1310          SLEVA: Prodej chaty 50 m², pozemek 792 m²
# 1348  SLEVA: Prodej rodinného domu 154 m², pozemek 8...
# 1377  SLEVA: Prodej rodinného domu 183 m², pozemek 5...
# 1402                      SLEVA: Prodej bytu 3+kk 65 m²
# 1462                    SLEVA: Pronájem bytu 1+kk 33 m²
# 1627  SLEVA: Prodej rodinného domu 130 m², pozemek 2...
# 1630                      SLEVA: Prodej bytu 2+kk 64 m²
# 1631  SLEVA: Prodej rodinného domu 178 m², pozemek 1...
# 1762      SLEVA: Prodej chalupy 200 m², pozemek 1034 m²
# 1763  SLEVA: Prodej rodinného domu 178 m², pozemek 6...
# 1788                      SLEVA: Prodej bytu 2+kk 60 m²
# 1823       SLEVA: Prodej chaty 1115 m², pozemek 1116 m²
# 1862  SLEVA: Prodej rodinného domu 90 m², pozemek 59...
# 1984                      SLEVA: Prodej bytu 2+kk 47 m²
# 2026          SLEVA: Prodej vily 208 m², pozemek 743 m²
# 2130  SLEVA: Prodej rodinného domu 90 m², pozemek 54...
# 2133  SLEVA: Prodej rodinného domu 190 m², pozemek 5...
# 2138  SLEVA: Prodej rodinného domu 185 m², pozemek 1...
# 2175                      SLEVA: Prodej bytu 3+1 100 m²
#
#                                          adress            price   type
# 6                                       Bohutín    15 499 000 Kč  sleva
# 103                   Křižíkova, Praha - Karlín     8 500 000 Kč  sleva
# 119                Balbínova, Praha - Vinohrady    10 990 000 Kč  sleva
# 120              Opletalova, Praha - Nové Město    14 500 000 Kč  sleva
# 121              Opletalova, Praha - Nové Město    23 900 000 Kč  sleva
# 137            Třebohostická, Praha - Strašnice    11 990 000 Kč  sleva
# 190            Nad Zlíchovem, Praha - Hlubočepy    21 000 000 Kč  sleva
# 225                 V oblouku, Praha - Nebušice  60 000 Kč/měsíc  sleva
# 233              Herčíkova, Brno - Královo Pole     7 590 000 Kč  sleva
# 281                            Krtská, Jesenice     1 990 000 Kč  sleva
# 282                            Krtská, Jesenice     1 990 000 Kč  sleva
# 302   Černá cesta, Olomouc - Klášterní Hradisko     4 690 000 Kč  sleva
# 349        Varenská, Ostrava - Moravská Ostrava  11 000 Kč/měsíc  sleva
# 387                                    Košetice     2 990 000 Kč  sleva
# 409         Račiněveská, Praha - Újezd nad Lesy    12 490 000 Kč  sleva
# 432                          Mladíkov, Jesenice    29 900 000 Kč  sleva
# 449                        Skalice nad Svitavou     7 154 100 Kč  sleva
# 467                          Vlašimská, Benešov     8 000 000 Kč  sleva
# 501                  Katovická, Praha - Bohnice  17 999 Kč/měsíc  sleva
# 624                 Zvonková, Havířov - Šumbark       899 000 Kč  sleva
# 738                Štítného, Kamenice nad Lipou     4 390 000 Kč  sleva
# 760                            Na Pěšině, Vráto     6 190 000 Kč  sleva
# 816                                     Loštice     4 490 000 Kč  sleva
# 880      Škroupova, Děčín - Děčín II-Nové Město     6 950 000 Kč  sleva
# 915                       Nová Bystřice - Albeř     6 290 000 Kč  sleva
# 1025               Ke Kapslovně, Praha - Žižkov    13 490 000 Kč  sleva
# 1138                       Chropyňská, Kroměříž     2 699 000 Kč  sleva
# 1144                       Chropyňská, Kroměříž     2 699 000 Kč  sleva
# 1249                Staré Město pod Landštejnem     1 990 000 Kč  sleva
# 1264                   Lázeňská, Horní Dvořiště     2 650 000 Kč  sleva
# 1290                    Chlum u Třeboně - Žíteč     4 490 000 Kč  sleva
# 1310                                   Komařice     1 260 000 Kč  sleva
# 1348                       Na Hájku, Suchohrdly    10 990 000 Kč  sleva
# 1377                Dlouhá, Hora Svaté Kateřiny       960 000 Kč  sleva
# 1402                     Meliorační, Horoměřice     6 250 000 Kč  sleva
# 1462                         Wolkerova, Olomouc  10 400 Kč/měsíc  sleva
# 1627                                     Hředle     1 900 000 Kč  sleva
# 1630                                   Morašice     2 950 000 Kč  sleva
# 1631                          Hobšovice - Skůry     6 200 000 Kč  sleva
# 1762                          Sněžnická, Jílové     5 542 000 Kč  sleva
# 1763                         Poděbradova, Hulín     4 500 000 Kč  sleva
# 1788              Pavla Beneše, Praha - Letňany     9 870 000 Kč  sleva
# 1823                        Milešov - Klenovice     6 490 000 Kč  sleva
# 1862                                   Výrovice     2 499 000 Kč  sleva
# 1984                 Český Krumlov - Domoradice     2 900 000 Kč  sleva
# 2026      Jeronýmova, Poděbrady - Poděbrady III    11 900 000 Kč  sleva
# 2130                                   Skotnice     7 249 000 Kč  sleva
# 2133            Koblovská, Ostrava - Petřkovice    10 000 000 Kč  sleva
# 2138                                     Útvina     5 700 000 Kč  sleva
# 2175                                     Křenov     1 599 000 Kč  sleva

# %%
# Creating TYPE column in dataframe copy
# Extracting first word from the name column - if the first word is 'SLEVA:', extracting the second word

df_copy = df.copy()

def extract_type(name):
    words = name.split()  
    if words[0].upper() == "SLEVA:":  
        if len(words) > 1: 
            return words[1].lower()  
    
    else: #if the first word is not 'SLEVA:'
        match = re.match(r'(\w+)', name)  # Extract the first word
        if match:
            return match.group(1).lower() 
    return None 

# Applying the function to the name column and creating the type column
df_copy['type'] = df_copy['name'].apply(extract_type)

# %% [markdown]
# ##### Creating column REAL-ESTATE "RE"

# %%
# Finding out what different kinds of real-estate are offered - second words in the name column (third, if the first word is 'SLEVA:')

# Splitting the name column into words
zoznam_slov=[]
for slovo in df['name']:
    slova = slovo.split()
    zoznam_slov.append(slova)

# checking all unique second words in the name column
druhe_slova = [x[1] for x in zoznam_slov]

druhe_slova_unique = list(set(druhe_slova))  
druhe_slova_unique
# Out:
# ['Pronájem',
#  'bytu',
#  'projektu',
#  'vily',
#  'chalupy',
#  'chaty',
#  'Prodej',
#  'památky',
#  'rodinného',
#  'vícegeneračního',
#  'zemědělské']

# %% [markdown]
# CONDITIONS FOR CREATING 'RE' COLUMN:
# 1. if the 1. word in NAME is SLEVA = take the 3. word - if the 3. word is ZEMEDELSKE, VICEGENERACNIHO, RODINNEHO = then take the 3. and 4. word (continuing of the 3. word)
# 2. if the 1. word is PREDAJ/PRONAJEM = take 2. word - if the 2. word is ZEMEDELSKE, VICEGENERACNIHO, RODINNEHO = then take 2. and 3. word

# %%
def extrahuj_RE(name):
    words = name.split()  # Split the name into words

    if words[0].upper() == "SLEVA:":
        if words[2].lower() in ["rodinného", "zemědělské", "vícegeneračního"]:
            words_re = words[2:4]
            return ' '.join(words_re).lower()
        else:
            return words[2].lower()
    elif words[0].lower() == "prodej" or words[0].lower() == "pronájem":
        if words[1].lower() in ["rodinného", "zemědělské", "vícegeneračního"]:
            words_re = words[1:3]
            return ' '.join(words_re).lower()
        else:
            return words[1].lower()



# Apply the function to the 'name' column and create the 'RE' column
df_copy['RE'] = df_copy['name'].apply(extrahuj_RE)

# %%
# Checking if there are any other different types of real-estate than the ones listed below

checkRE = df_copy[(df_copy['RE'] != 'rodinného domu') & (df_copy['RE'] != 'bytu') & (df_copy['RE'] != 'vícegeneračního domu') & (df_copy['RE'] != 'zemědělské usedlosti') & (df_copy['RE'] != 'vily') & (df_copy['RE'] != 'chalupy') & (df_copy['RE'] != 'chaty') & (df_copy['RE'] != 'památky') & (df_copy['RE'] != 'projektu')]
checkRE
# Out:
# Empty DataFrame
# Columns: [name, adress, price, type, RE]
# Index: []

# %% [markdown]
# ##### Creating column "area_m2"
# Conditions:
# 1. If RE = "bytu" (apartment), then look for the next number after the disposition of the flat (e.g. 2+kk / 3+1)

# %%
def extract_area(name, re_type):
    if re_type == 'bytu':
        area_bytu = re.findall(r'\d\+\w* (\d*)', name)
        if area_bytu:
            return area_bytu[0] # findall returns list
    else:
        area = re.findall(r'(\d+)', name)  # find all numbers in the NAME column
        if area:
            return area[0] # return just the first number = area of a real estate
    return None 

df_copy['area_m2'] = df_copy.apply(lambda row: extract_area(row['name'], row['RE']), axis=1)

# %% [markdown]
# ##### Creating columns "land_area"
# Conditions: <br>
# 1. if RE = bytu, then there is no LAND AREA

# %%
def extract_land(name, re_type):
    if re_type == 'bytu':
        return None
    else:
        area = re.findall(r'(\d+)', name)  # find numbers
        if area:
            return area[1]  # return the second number = land area
    return None  

df_copy['land_area_m2'] = df_copy.apply(lambda row: extract_land(row['name'], row['RE']), axis=1)

# %% [markdown]
# ##### Creating column "disposition"
# Disposition apply only tu RE TYPE = byt

# %%
def extract_dispo(name, re_type):
    if re_type == 'bytu':
        dispo_bytu = re.findall(r'(\d\+\w*)', name)
        if dispo_bytu:
            return dispo_bytu[0]
    else:
        return None
    return None

df_copy['disposition'] = df_copy.apply(lambda row: extract_dispo(row['name'], row['RE']), axis=1)

# %% [markdown]
# ##### Creating column "city" and "city_part"
# * if there is only 1 word in column ADRESS = write it to new column CITY<br>
# * if there are more words - city is written after coma<br>
# * there can be a dash after city and written a city part in the end

# %%
def extract_city(adress):
    adress_line = adress.split()
    if len(adress_line) == 1:
        return adress, None  # Single word: village, no city part
    else:
        city_match = re.search(r"([^-,\n]+)(?:\s*-\s*([^,\n]+))?$", adress)
        if city_match:
            city = city_match.group(1).strip() #remove spaces
            city_part = city_match.group(2).strip() if city_match.group(2) else None #remove spaces
            return city, city_part
        else:
            return None, None  # No match, return None for both

df_copy[['city', 'city_part']] = df_copy['adress'].apply(lambda x: pd.Series(extract_city(x)))

# %% [markdown]
# ##### Creating column "price_KC"

# %%
def extract_price(price_str):
    try:
        # 1. Encode to UTF-8 and decode to ASCII, ignoring errors
        price_str = price_str.encode('utf-8').decode('ascii', errors='ignore')

        match = re.search(r'([\d\s,]+)', price_str)
        if match:
            price_str = match.group(1).replace(' ', '').replace(',', '')
            return int(price_str)
        return None
    except (ValueError, AttributeError):
        return None

df_copy['price_KC'] = df_copy['price'].apply(extract_price)

df_copy
# Out:
#                                               name  \
# 0                          Pronájem bytu 2+1 60 m²
# 1                            Prodej bytu 1+1 35 m²
# 2            Prodej chalupy 110 m², pozemek 331 m²
# 3     Prodej rodinného domu 110 m², pozemek 331 m²
# 4     Prodej rodinného domu 250 m², pozemek 800 m²
# ...                                            ...
# 2195                        Prodej bytu 3+kk 86 m²
# 2196                       Prodej bytu 4+kk 125 m²
# 2197                         Prodej bytu 1+1 38 m²
# 2198                         Prodej bytu 3+1 81 m²
# 2199                        Prodej bytu 1+kk 24 m²
#
#                                  adress            price      type  \
# 0          Pod Lesem, Plzeň - Doubravka  15 500 Kč/měsíc  pronájem
# 1     Úvalská, Karlovy Vary - Drahovice     2 600 000 Kč    prodej
# 2                             Sopotnice     1 890 000 Kč    prodej
# 3                             Sopotnice     1 890 000 Kč    prodej
# 4                                 Jičín     5 890 000 Kč    prodej
# ...                                 ...              ...       ...
# 2195                               Srní     9 890 000 Kč    prodej
# 2196                Karlovarská, Unhošť     7 999 000 Kč    prodej
# 2197          Košická, Praha - Vršovice     5 999 999 Kč    prodej
# 2198        Rostovská, Praha - Vršovice    14 857 931 Kč    prodej
# 2199    Aloise Rašína, Olomouc - Řepčín     3 250 000 Kč    prodej
#
#                   RE area_m2 land_area_m2 disposition          city  \
# 0               bytu      60         None         2+1         Plzeň
# 1               bytu      35         None         1+1  Karlovy Vary
# 2            chalupy     110          331        None     Sopotnice
# 3     rodinného domu     110          331        None     Sopotnice
# 4     rodinného domu     250          800        None         Jičín
# ...              ...     ...          ...         ...           ...
# 2195            bytu      86         None        3+kk          Srní
# 2196            bytu     125         None        4+kk        Unhošť
# 2197            bytu      38         None         1+1         Praha
# 2198            bytu      81         None         3+1         Praha
# 2199            bytu      24         None        1+kk       Olomouc
#
#       city_part    price_KC
# 0     Doubravka     15500.0
# 1     Drahovice   2600000.0
# 2          None   1890000.0
# 3          None   1890000.0
# 4          None   5890000.0
# ...         ...         ...
# 2195       None   9890000.0
# 2196       None   7999000.0
# 2197   Vršovice   5999999.0
# 2198   Vršovice  14857931.0
# 2199     Řepčín   3250000.0
#
# [2200 rows x 11 columns]

# %%
# CREATING A CSV FILE
df_copy.to_csv('real_estate_clean.csv', index=False)
